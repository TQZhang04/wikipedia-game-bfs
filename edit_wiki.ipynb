# %%
import pandas as pd

# %%
df = pd.read_csv('wiki.csv', sep='\t')

# %%
df.head(20)
# Out:
#     page_id_from      page_title_from  page_id_to           page_title_to
# 0             10  AccessibleComputing      411964  Computer accessibility
# 1             12            Anarchism     5013592  6 February 1934 crisis
# 2             12            Anarchism     2181459           Abstentionism
# 3             12            Anarchism      839656             Adolf Brand
# 4             12            Anarchism     2731583            Adolf Hitler
# 5             12            Anarchism      192008          Adolphe Thiers
# 6             12            Anarchism      729048          Affinity group
# 7             12            Anarchism       30758    Age of Enlightenment
# 8             12            Anarchism         627             Agriculture
# 9             12            Anarchism      710931                AK Press
# 10            12            Anarchism         983            Albert Camus
# 11            12            Anarchism      304035          Albert Meltzer
# ...

# %%
query = ["Data science",
         "Computer science",
         "Python (programming language)", 
         "Java (programming language)",
         "SQL",
         "JavaScript",
         "Statistics", 
         "pandas (software)", 
         "D3.js"
        ]

# %%
final = df[df["page_title_from"].isin(query) & df["page_title_to"].isin(query)]
final

# %%
final.to_csv('small_wiki.csv', index=False)
